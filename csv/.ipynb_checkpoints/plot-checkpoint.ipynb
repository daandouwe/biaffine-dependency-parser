# %%
# %pylab inline

import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
loss = pd.read_csv('loss.train.csv')
train_acc = pd.read_csv('acc.train.csv')
val_acc = pd.read_csv('acc.val.csv')

# %%
loss.plot()

# %%
train_acc.plot()

# %%
val_acc.plot()
